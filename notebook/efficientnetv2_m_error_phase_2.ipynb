# %% [markdown]
# # 🧠 Brain Tumor MRI Classification — 30 Classes (v2)
#
# **Model:** EfficientNetV2-M (Transfer Learning)
# **Dataset:** fernando2rad/brain-tumor-mri-images-30-classes (Kaggle)
#
# ---
#
# ## 🔧 Thay đổi so với v1
# | | v1 | v2 |
# |---|---|---|
# | IMG_SIZE | 480×480 | **384×384** (nhẹ hơn, ít overfit hơn) |
# | Loss | CrossEntropy + class_weight | **Focal Loss** (xử lý imbalance tốt hơn) |
# | Augmentation | Nhẹ | **Mạnh hơn** (MixUp, RandomErasing, GridDistortion) |
# | Dropout | 0.4 | **0.5** |
# | Head | Dense(512) | **Dense(512) → Dense(256)** (thêm 1 lớp) |
# | Weight decay | Không | **AdamW + 1e-4** |
# | Monitor | val_accuracy | **val_f1_macro** |
# | Class weights | Dùng với CE | Không cần (Focal Loss tự xử lý) |
#
# ---
#
# ## 📋 Mục lục
# 1. Cài đặt & Import thư viện
# 2. Tải Dataset từ Kaggle
# 3. Khám phá & Chuẩn bị dữ liệu
# 4. Split dữ liệu theo Class (giữ phân phối nhãn)
# 5. Tạo Data Pipeline (tf.data) — augmentation mạnh
# 6. Focal Loss + F1 Macro Metric
# 7. Xây dựng Model EfficientNetV2-M v2
# 8. Kiểm tra Checkpoint & Resume Training
# 9. Phase 1 — Train (Freeze Backbone)
# 10. Phase 2 — Fine-tune (Unfreeze dần)
# 11. Visualize Learning Curves
# 12. Đánh giá trên Test Set
# 13. Visualize Kết quả Dự đoán
#
# ---
#
# ### ⚠️ Lưu ý quan trọng
# - Split theo **class_name** để giữ phân phối nhãn ổn định
# - **Focal Loss** tự xử lý imbalance (không cần class_weight riêng)
# - Monitor **val_f1_macro** thay vì val_accuracy để chọn best checkpoint
# - Phase 2 unfreeze **từng block** từ top xuống, không unfreeze hết cùng lúc

# %% [markdown]
# ## 1. Cài đặt & Import thư viện

# %%
# !pip install -q kagglehub scikit-learn

# %%
import os
import re
import glob
import json
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from pathlib import Path
from collections import defaultdict

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetV2M
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping,
    ReduceLROnPlateau, CSVLogger, LambdaCallback
)

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, f1_score
)

import kagglehub
import warnings
warnings.filterwarnings('ignore')

# ── Seed cố định ──
RANDOM_SEED = 32
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)

print('✅ Import xong!')
print(f'TensorFlow version: {tf.__version__}')
# Out:
# 2026-06-24 07:44:58.535458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782287098.731717      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782287098.795655      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782287099.294890      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782287099.294927      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782287099.294929      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782287099.294932      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ✅ Import xong!
# TensorFlow version: 2.19.0

# %%
gpus = tf.config.list_physical_devices('GPU')
print(f'Số GPU khả dụng: {len(gpus)}')
for i, gpu in enumerate(gpus):
    print(f'  GPU {i}: {gpu.name}')

strategy = tf.distribute.MirroredStrategy()
print(f'\n🚀 Số thiết bị trong strategy: {strategy.num_replicas_in_sync}')
# Out:
# Số GPU khả dụng: 2
#   GPU 0: /physical_device:GPU:0
#   GPU 1: /physical_device:GPU:1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
#
# 🚀 Số thiết bị trong strategy: 2
# I0000 00:00:1782287118.119806      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782287118.126046      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# ══════════════════════════════════════
#   CẤU HÌNH TOÀN CỤC (chỉnh ở đây)
# ══════════════════════════════════════

IMG_SIZE      = 384          # ↓ từ 480 → giảm overfitting, tốc độ tốt hơn
BATCH_SIZE    = 56           # 16 per GPU × 2 GPU
NUM_CLASSES   = 30
RANDOM_SEED   = 32

# Split ratio: 70 / 15 / 15 (theo class)
VAL_RATIO     = 0.15
TEST_RATIO    = 0.15

# Train từ đầu sau khi đổi split / pipeline
START_FROM_SCRATCH = True

# Phase 1: Freeze backbone
PHASE1_EPOCHS = 15           # ↑ từ 10 → cho head ổn định hơn trước khi unfreeze
PHASE1_LR     = 1e-3

# Phase 2: Unfreeze fine-tune (dần dần)
PHASE2_EPOCHS = 30
PHASE2_LR     = 1e-4         # ↑ tăng LR để hội tụ nhanh hơn

# Focal Loss params
FOCAL_GAMMA   = 2.0          # focus vào hard examples
FOCAL_ALPHA   = 0.25         # cân bằng positive/negative

# Thư mục lưu
CKPT_DIR      = '/kaggle/working/checkpoints'
BEST_WEIGHT   = '/kaggle/working/best_weights.weights.h5'
LOG_CSV       = '/kaggle/working/training_log.csv'

os.makedirs(CKPT_DIR, exist_ok=True)
print('✅ Cấu hình xong!')
print(f'  IMG_SIZE    : {IMG_SIZE}×{IMG_SIZE}  (↓ từ 480)')
print(f'  BATCH_SIZE  : {BATCH_SIZE}')
print(f'  NUM_CLASSES : {NUM_CLASSES}')
print(f'  Phase1 LR   : {PHASE1_LR}  | {PHASE1_EPOCHS} epochs')
print(f'  Phase2 LR   : {PHASE2_LR}  | {PHASE2_EPOCHS} epochs')
print(f'  Focal gamma : {FOCAL_GAMMA} | alpha: {FOCAL_ALPHA}')
print(f'  Split       : 70/15/15 theo class')
print(f'  Start fresh : {START_FROM_SCRATCH}')
# Out:
# ✅ Cấu hình xong!
#   IMG_SIZE    : 384×384  (↓ từ 480)
#   BATCH_SIZE  : 56
#   NUM_CLASSES : 30
#   Phase1 LR   : 0.001  | 15 epochs
#   Phase2 LR   : 0.0001  | 30 epochs
#   Focal gamma : 2.0 | alpha: 0.25
#   Split       : 70/15/15 theo class
#   Start fresh : True

# %% [markdown]
# ## 2. Tải Dataset từ Kaggle

# %%
path = kagglehub.dataset_download('fernando2rad/brain-tumor-mri-images-30-classes')
print(f'Dataset path: {path}')

# Liệt kê cấu trúc thư mục
for root, dirs, files in os.walk(path):
    level = root.replace(path, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 2:
        subindent = ' ' * 2 * (level + 1)
        for f in files[:3]:
            print(f'{subindent}{f}')
        if len(files) > 3:
            print(f'{subindent}... ({len(files)} files total)')
# Out:
# Dataset path: /kaggle/input/datasets/fernando2rad/brain-tumor-mri-images-30-classes
# brain-tumor-mri-images-30-classes/
#   DATA.json
#   Astrocytoma T2/
#     T2 - Diffuse astrocytoma frontal , temporal 012.jpg
#     T2 - Pilocytic astrocytoma posterior fossa , ventricle 028.jpg
#     T2 - Pilocytic astrocytoma ventricle 046.jpg
#     ... (281 files total)
#   Neurocytoma T1C+/
#     T1C+ - Central neurocytoma 048.jpg
#     T1C+ - Extraventricular neurocytoma frontal 010.jpg
#     T1C+ - Central neurocytoma ventricle 005.jpg
#     ... (254 files total)
#   Glioma T1/
#     T1 - Low grade glioma 004.jpg
#     T1 - High grade glioma, NOS grade 4 temporal , basal ganglia 088.jpg
#     T1 - Thalamic glioma ventricle , supratentorial 049.jpg
#     ... (522 files total)
#   Schwannoma T1C+/
#     T1C+ - Multicompartmental trigeminal schwannoma middle cranial fossa , temporal 103.jpg
#     T1C+ - Trigeminal schwannoma cerebellopontine angle , trigeminal 009.jpg
#     T1C+ - Vestibular schwannoma intracanalicular , brainstem 011.jpg
#     ... (564 files total)
#   Hemangiopericytoma T2/
#     T2 - Solitary fibrous tumor (hemangiopericytoma) with peritumoural bleeding temporal , ventricle 026.jpg
#     T2 - Solitary fibrous tumor (hemangiopericytoma) falx 055.jpg
#     T2 - Solitary fibrous tumor - hemangiopericytoma ventricle 012.jpg
#     ... (118 files total)
#   Meningioma T2/
#     T2 - Meningioma frontal 063.jpg
#     T2 - Pediatric meningioma falx , occipital 001.jpg
#     T2 - Choroid plexus metastasis - from renal cell carcinoma temporal , ventricle 003.jpg
#     ... (458 files total)
#   Oligodendroglioma T1C+/
#     T1C+ - Oligodendroglioma 008.jpg
#     T1C+ - Oligodendroglioma (grade 3) temporal , basal ganglia 001.jpg
#     T1C+ - Oligodendroglioma frontal 104.jpg
#     ... (192 files total)
#   Other T1C+/
#     T1C+ - Acoustic neuroma cerebellopontine angle , trigeminal 004.jpg
#     T1C+ - Arachnoid cyst middle cranial fossa 032.jpg
#     T1C+ - Colloid cyst ventricle 015.jpg
#     ... (756 files total)
#   Ependymoma T2/
#     T2 - Supratentorial ependymoma frontal 014.jpg
#     T2 - Posterior fossa ependymoma supratentorial 017.jpg
#     T2 - Posterior fossa ependymoma supratentorial 029.jpg
#     ... (350 files total)
#   Ependymoma T1C+/
#     T1C+ - Supratentorial ependymoma 029.jpg
#     T1C+ - Ependymoma ventricle , brainstem 060.jpg
#     T1C+ - Supratentorial ependymoma frontal 032.jpg
#     ... (374 files total)
#   Glioma T2/
#     T2 - Bilateral thalamic glioma ventricle 004.jpg
#     T2 - Diffuse glioma 002.jpg
#     T2 - Optochiasmatic glioma suprasellar 003.jpg
#     ... (405 files total)
#   Meningioma T1/
#     T1 - Intraventricular meningioma ventricle , temporal 117.jpg
#     T1 - Microcystic meningioma frontal , ventricle 048.jpg
#     T1 - Angiomatous meningioma anterior cranial fossa , frontal 005.jpg
#     ... (636 files total)
#   Astrocytoma T1C+/
#     T1C+ - Pilocytic astrocytoma posterior fossa , ventricle 073.jpg
#     T1C+ - Diffuse astrocytoma NOS frontal 018.jpg
#     T1C+ - Pilocytic astrocytoma ventricle , temporal 016.jpg
#     ... (441 files total)
#   Astrocytoma T1/
#     T1 - Pilocytic astrocytoma posterior fossa , ventricle 015.jpg
#     T1 - Diffuse fibrillary astrocytoma temporal 006.jpg
#     T1 - Pilocytic astrocytoma - supratentorial 022.jpg
#     ... (396 files total)
#   Ependymoma T1/
#     T1 - Ependymoma posterior fossa , ventricle 001.jpg
#     T1 - Ependymoma ventricle , brainstem 041.jpg
#     T1 - Supratentorial ependymoma frontal 017.jpg
#     ... (313 files total)
#   Meningioma T1C+/
#     T1C+ - Meningioma frontal 129.jpg
#     T1C+ - Microcystic meningioma frontal , ventricle 055.jpg
#     T1C+ - Pediatric meningioma falx , occipital 037.jpg
#     ... (977 files total)
#   Neurocytoma T1/
#     T1 - Central neurocytoma 046.jpg
#     T1 - Central neurocytoma 024.jpg
#     T1 - Central neurocytoma ventricle 069.jpg
#     ... (190 files total)
#   Normal T1/
#     T1 - Normal brain MRI (non-focal epilepsy protocol) 063.jpg
#     T1 - MRI brain - normal (70-year-old) ventricle , brainstem 239.jpg
#     T1 - Normal brain MRI (TLE protocol) temporal 108.jpg
#     ... (415 files total)
#   Glioma T1C+/
#     T1C+ - High grade glioma, NOS grade 4 temporal , basal ganglia 084.jpg
#     T1C+ - Malignant degeneration of low grade glioma ventricle 010.jpg
#     T1C+ - Ganglioglioma temporal 008.jpg
#     ... (549 files total)
#   Oligodendroglioma T2/
#     T2 - Oligodendroglioma NOS 001.jpg
#     T2 - Oligodendroglioma frontal 039.jpg
#     T2 - Oligodendroglioma NOS 007.jpg
#     ... (137 files total)
#   Schwannoma T2/
#     T2 - Vestibular schwannoma cerebellopontine angle , ventricle 015.jpg
#     T2 - Meningioma mimicking vestibular schwannoma cerebellopontine angle , ventricle 007.jpg
#     T2 - Trigeminal schwannoma trigeminal , cerebellopontine angle 217.jpg
#     ... (309 files total)
#   Schwannoma T1/
#     T1 - Vestibular schwannoma cerebellopontine angle 020.jpg
#     T1 - Trigeminal schwannoma ventricle 138.jpg
#     T1 - Trigeminal schwannoma ventricle 175.jpg
#     ... (363 files total)
#   Other T1/
#     T1 - Arachnoid cyst middle cranial fossa 008.jpg
#     T1 - Pineal cyst pineal 011.jpg
#     T1 - Colloid cyst ventricle 001.jpg
#     ... (412 files total)
#   Hemangiopericytoma T1C+/
#     T1C+ - Solitary fibrous tumor (hemangiopericytoma) occipital 021.jpg
#     T1C+ - Solitary fibrous tumor (hemangiopericytoma) 061.jpg
#     T1C+ - Solitary fibrous tumor (hemangiopericytoma) with peritumoural bleeding temporal , ventricle 053.jpg
#     ... (307 files total)
#   Normal T2/
#     T2 - Normal brain MRI 120.jpg
#     T2 - Normal MRI brain - neurodegenerative protocol temporal 009.jpg
#     T2 - Normal brain MRI with post-contrast FLAIR 036.jpg
#     ... (379 files total)
#   Hemangiopericytoma T1/
#     T1 - Solitary fibrous tumor (hemangiopericytoma) with peritumoural bleeding temporal , ventricle 067.jpg
#     T1 - Solitary fibrous tumor (hemangiopericytoma) with peritumoural bleeding temporal , ventricle 101.jpg
#     T1 - Solitary fibrous tumor (hemangiopericytoma) falx 046.jpg
#     ... (178 files total)
#   Normal T1C+/
#     T1C+ - Normal brain MRI with post-contrast FLAIR 060.jpg
#     T1C+ - MRI brain - normal (70-year-old) ventricle , brainstem 042.jpg
#     T1C+ - MRI brain - normal (70-year-old) ventricle , brainstem 124.jpg
#     ... (264 files total)
#   Neurocytoma T2/
#     T2 - Central neurocytoma ventricle 033.jpg
#     T2 - Central neurocytoma intraventricular , ventricle 041.jpg
#     T2 - Central neurocytoma intraventricular , ventricle 010.jpg
#     ... (174 files total)
#   Oligodendroglioma T1/
#     T1 - Oligodendroglioma 012.jpg
#     T1 - Oligodendroglioma frontal 146.jpg
#     T1 - Oligodendroglioma (grade 3) frontal , ventricle 013.jpg
#     ... (221 files total)
#   Other T2/
#     T2 - Solitary fibrous tumor of the dura occipital 020.jpg
#     T2 - Choroid plexus carcinoma ventricle , frontal 046.jpg
#     T2 - Intraventricular metastasis from renal cell carcinoma ventricle 009.jpg
#     ... (365 files total)

# %% [markdown]
# ## 3. Khám phá & Chuẩn bị dữ liệu

# %%
# ── Thu thập tất cả file ảnh ──
all_files = []
for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
    all_files.extend(glob.glob(os.path.join(path, '**', ext), recursive=True))

print(f'Tổng số file ảnh: {len(all_files):,}')

# ── Tạo DataFrame ──
records = []
for fp in all_files:
    parts = Path(fp).parts
    class_name = parts[-2]   # thư mục cha = tên class
    records.append({'filepath': fp, 'class_name': class_name})

df = pd.DataFrame(records)

# ── Encode label ──
CLASS_NAMES = sorted(df['class_name'].unique().tolist())
class2idx = {c: i for i, c in enumerate(CLASS_NAMES)}
df['label'] = df['class_name'].map(class2idx)

print(f'Số class      : {NUM_CLASSES}')
print(f'Số ảnh unique : {len(df):,}')
print(f'Số class thực : {df["class_name"].nunique():,}')
print(f'\nTop class phân phối:')
print(df['class_name'].value_counts())
# Out:
# Tổng số file ảnh: 11,300
# Số class      : 30
# Số ảnh unique : 11,300
# Số class thực : 30
#
# Top class phân phối:
# class_name
# Meningioma T1C+            977
# Other T1C+                 756
# Meningioma T1              636
# Schwannoma T1C+            564
# Glioma T1C+                549
# Glioma T1                  522
# Meningioma T2              458
# Astrocytoma T1C+           441
# Normal T1                  415
# Other T1                   412
# Glioma T2                  405
# Astrocytoma T1             396
# Normal T2                  379
# Ependymoma T1C+            374
# Other T2                   365
# Schwannoma T1              363
# Ependymoma T2              350
# Ependymoma T1              313
# Schwannoma T2              309
# Hemangiopericytoma T1C+    307
# Astrocytoma T2             281
# Normal T1C+                264
# Neurocytoma T1C+           254
# Oligodendroglioma T1       221
# Oligodendroglioma T1C+     192
# Neurocytoma T1             190
# Hemangiopericytoma T1      178
# Neurocytoma T2             174
# Oligodendroglioma T2       137
# Hemangiopericytoma T2      118
# Name: count, dtype: int64

# %%
# ── Visualize phân phối class ──
fig, ax = plt.subplots(figsize=(16, 5))
counts = df['class_name'].value_counts()
colors = plt.cm.RdYlGn(np.linspace(0.2, 0.8, len(counts)))
ax.bar(counts.index, counts.values, color=colors, edgecolor='white')
ax.set_xticklabels(counts.index, rotation=45, ha='right', fontsize=8)
ax.set_ylabel('Số lượng ảnh')
ax.set_title('Phân phối ảnh theo class\n(Imbalance ratio: {:.1f}x)'.format(
    counts.max() / counts.min()))
ax.axhline(counts.mean(), color='navy', linestyle='--', label=f'Trung bình: {counts.mean():.0f}')
ax.legend()
plt.tight_layout()
plt.show()

print(f'\nMin samples/class: {counts.min()} ({counts.idxmin()})')
print(f'Max samples/class: {counts.max()} ({counts.idxmax()})')
print(f'Imbalance ratio  : {counts.max()/counts.min():.1f}x')
# Out:
# Min samples/class: 118 (Hemangiopericytoma T2)
# Max samples/class: 977 (Meningioma T1C+)
# Imbalance ratio  : 8.3x

# %% [markdown]
# ## 4. Split dữ liệu theo Class (giữ phân phối nhãn)

# %%
# ── Split theo class label để giữ phân phối nhãn ổn định ──
# Mỗi ảnh là một sample; split stratified theo class
train_idx, valtest_idx = train_test_split(
    df.index,
    test_size=VAL_RATIO + TEST_RATIO,
    stratify=df['label'],
    random_state=RANDOM_SEED
)

valtest_df = df.loc[valtest_idx].copy()
val_idx, test_idx = train_test_split(
    valtest_df.index,
    test_size=TEST_RATIO / (VAL_RATIO + TEST_RATIO),
    stratify=valtest_df['label'],
    random_state=RANDOM_SEED
)

# Kiểm tra không có overlap theo index gốc
assert len(set(train_idx) & set(val_idx)) == 0
assert len(set(train_idx) & set(test_idx)) == 0
assert len(set(val_idx) & set(test_idx)) == 0

train_df = df.loc[train_idx].reset_index(drop=True)
val_df   = df.loc[val_idx].reset_index(drop=True)
test_df  = df.loc[test_idx].reset_index(drop=True)

print('✅ Split xong (theo class_name):')
print(f'  Train: {len(train_df):>6,} ảnh')
print(f'  Val  : {len(val_df):>6,} ảnh')
print(f'  Test : {len(test_df):>6,} ảnh')
print(f'\n  Tỉ lệ thực tế: {len(train_df)/len(df)*100:.1f}% / {len(val_df)/len(df)*100:.1f}% / {len(test_df)/len(df)*100:.1f}%')
print('\n✅ Không có overlap giữa các split!')
# Out:
# ✅ Split xong (theo class_name):
#   Train:  7,910 ảnh
#   Val  :  1,695 ảnh
#   Test :  1,695 ảnh
#
#   Tỉ lệ thực tế: 70.0% / 15.0% / 15.0%
#
# ✅ Không có overlap giữa các split!

# %% [markdown]
# ## 5. Tạo Data Pipeline (tf.data) — Augmentation mạnh
#
# **Thay đổi so với v1:**
# - Thêm `RandomErasing` (xóa ngẫu nhiên vùng ảnh)
# - Thêm `GridDistortion` (biến dạng lưới — tốt cho medical imaging)
# - Thêm `MixUp` (trộn 2 ảnh + nhãn)
# - Tăng cường rotation, zoom, brightness/contrast
# - `MixUp` chỉ áp dụng cho **train set**

# %%
AUTOTUNE = tf.data.AUTOTUNE

# ── Hàm đọc & resize ảnh ──
def load_image(filepath, label):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)   # [0, 255] — EfficientNetV2M tự normalize
    return img, label

def _rotate(img, angle):
    from tensorflow.keras.preprocessing.image import apply_affine_transform
    result = apply_affine_transform(img.numpy(), theta=float(angle.numpy()) * 57.3)
    return tf.cast(result, tf.float32)
    
# ── Augmentation mạnh cho train ──
def augment_train(img, label, use_color_jitter=True):
    # Flip
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)

    # ✅ Bọc trong py_function → chạy eager, được dùng .numpy()
    angle = tf.random.uniform([], -0.26, 0.26)
    img = tf.py_function(func=_rotate, inp=[img, angle], Tout=tf.float32)
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])  # ⚠️ Bắt buộc set lại shape

    # Zoom (crop + resize)
    scale = tf.random.uniform([], 0.80, 1.0)
    h = tf.cast(IMG_SIZE * scale, tf.int32)
    w = tf.cast(IMG_SIZE * scale, tf.int32)
    img = tf.image.random_crop(img, [h, w, 3])
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])

    # Brightness & Contrast
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, 0.9, 1.1)

    # Saturation & Hue: chỉ dùng cho phase 1
    if use_color_jitter:
        img = tf.image.random_saturation(img, 0.9, 1.1)
        img = tf.image.random_hue(img, 0.03)

    # Random Erasing
    def random_erasing(img):
        erase_h = tf.random.uniform([], 20, IMG_SIZE // 5, dtype=tf.int32)
        erase_w = tf.random.uniform([], 20, IMG_SIZE // 5, dtype=tf.int32)
        top  = tf.random.uniform([], 0, IMG_SIZE - erase_h, dtype=tf.int32)
        left = tf.random.uniform([], 0, IMG_SIZE - erase_w, dtype=tf.int32)
        mask = tf.ones([erase_h, erase_w, 3], dtype=tf.float32) * 128.0
        padding = [[top, IMG_SIZE - top - erase_h],
                   [left, IMG_SIZE - left - erase_w],
                   [0, 0]]
        mask_full = tf.pad(mask, padding)
        erase_mask = tf.ones([IMG_SIZE, IMG_SIZE, 3], dtype=tf.float32)
        erase_mask = erase_mask - tf.cast(mask_full > 0, tf.float32)
        return img * erase_mask + mask_full

    img = tf.cond(
        tf.random.uniform([]) > 0.5,
        lambda: random_erasing(img),
        lambda: img
    )

    img = tf.clip_by_value(img, 0.0, 255.0)
    return img, label


# ── MixUp ──
def mixup_batch(images, labels, alpha=0.1):
    """Apply MixUp augmentation trên 1 batch."""
    batch_size = tf.shape(images)[0]
    
    lam = tf.random.uniform([batch_size], 0.0, 1.0)
    lam = tf.maximum(lam, 1 - lam)
    lam = tf.reshape(lam, [batch_size, 1, 1, 1])

    idx      = tf.random.shuffle(tf.range(batch_size))
    mixed_x  = lam * images + (1 - lam) * tf.gather(images, idx)
    lam_flat = tf.reshape(lam, [batch_size])

    y1 = tf.one_hot(labels, NUM_CLASSES)
    y2 = tf.one_hot(tf.gather(labels, idx), NUM_CLASSES)
    mixed_y  = tf.reshape(lam_flat, [batch_size, 1]) * y1 + \
               tf.reshape(1 - lam_flat, [batch_size, 1]) * y2

    mixed_x = tf.cast(mixed_x, tf.float32)
    return mixed_x, mixed_y


# ── Build datasets ──
def build_dataset(data_df, training=False, mixup=False, color_aug=True):
    filepaths = data_df['filepath'].values
    labels    = data_df['label'].values.astype(np.int32)

    ds = tf.data.Dataset.from_tensor_slices((filepaths, labels))

    if training:
        ds = ds.shuffle(len(data_df), seed=RANDOM_SEED, reshuffle_each_iteration=True)

    ds = ds.map(load_image, num_parallel_calls=AUTOTUNE)

    if training:
        ds = ds.map(
            lambda x, y: augment_train(x, y, use_color_jitter=color_aug),
            num_parallel_calls=AUTOTUNE
        )

    ds = ds.batch(BATCH_SIZE, drop_remainder=training)

    if training and mixup:
        ds = ds.map(
            lambda x, y: mixup_batch(x, y, alpha=0.1),
            num_parallel_calls=AUTOTUNE
        )

    ds = ds.prefetch(AUTOTUNE)
    return ds


train_ds = build_dataset(train_df, training=True,  mixup=True,  color_aug=True)
train_ds_p2 = build_dataset(train_df, training=True, mixup=False, color_aug=False)
val_ds   = build_dataset(val_df,   training=False, mixup=False)
test_ds  = build_dataset(test_df,  training=False, mixup=False)

print('✅ Dataset pipeline xong!')
print(f'  Train batches   : {len(train_ds)}')
print(f'  Train P2 batches: {len(train_ds_p2)}')
print(f'  Val   batches    : {len(val_ds)}')
print(f'  Test  batches    : {len(test_ds)}')
print(f'\n  Phase 1 aug : flip, rotate, zoom, color jitter, erasing, MixUp')
print(f'  Phase 2 aug : flip, rotate, zoom, brightness/contrast nhẹ, erasing')
# Out:
# ✅ Dataset pipeline xong!
#   Train batches   : 141
#   Train P2 batches: 141
#   Val   batches    : 31
#   Test  batches    : 31
#
#   Phase 1 aug : flip, rotate, zoom, color jitter, erasing, MixUp
#   Phase 2 aug : flip, rotate, zoom, brightness/contrast nhẹ, erasing

# %%
# ── Visualize augmented samples ──
fig, axes = plt.subplots(2, 8, figsize=(20, 6))

# Ảnh gốc (val_ds)
for i, (imgs, lbls) in enumerate(val_ds.take(1)):
    for j in range(8):
        ax = axes[0, j]
        ax.imshow(imgs[j].numpy().astype(np.uint8))
        ax.set_title(CLASS_NAMES[lbls[j].numpy()], fontsize=6)
        ax.axis('off')

# Ảnh augmented (train_ds — sau MixUp labels là soft)
for i, (imgs, lbls) in enumerate(train_ds.take(1)):
    for j in range(8):
        ax = axes[1, j]
        ax.imshow(tf.cast(imgs[j], tf.uint8).numpy())
        dominant = CLASS_NAMES[np.argmax(lbls[j].numpy())]
        ax.set_title(f'aug: {dominant}', fontsize=6)
        ax.axis('off')

axes[0, 0].set_ylabel('Original', fontsize=9, rotation=0, labelpad=50)
axes[1, 0].set_ylabel('Augmented', fontsize=9, rotation=0, labelpad=45)
plt.suptitle('Augmentation samples (top: original, bottom: augmented+MixUp)', fontsize=12)
plt.tight_layout()
plt.savefig('/kaggle/working/augmentation_samples.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Focal Loss + F1 Macro Metric
#
# **Tại sao Focal Loss?**
# - CrossEntropy với class_weight giúp nhưng vẫn bị dominated bởi easy examples
# - Focal Loss thêm factor `(1 - p_t)^gamma` — giảm loss của easy examples, tăng focus vào hard/minority examples
# - Không cần điều chỉnh class_weight thủ công
#
# **Tại sao monitor F1 Macro?**
# - Accuracy dễ bị mislead bởi class đông
# - F1 Macro tính trung bình không weighted → phát hiện ngay khi model học kém 1 class nào đó

# %%
class FocalLoss(tf.keras.losses.Loss):
    """
    Focal Loss cho multi-class classification.
    FL(p_t) = -alpha_t * (1 - p_t)^gamma * log(p_t)

    Hỗ trợ cả hard labels (integer) và soft labels (one-hot / MixUp).
    """
    def __init__(self, gamma=2.0, alpha=0.25, name='focal_loss', **kwargs):
        super().__init__(name=name, **kwargs)
        self.gamma = gamma
        self.alpha = alpha

    def call(self, y_true, y_pred):
        y_pred = tf.cast(y_pred, tf.float32)
        y_true = tf.cast(y_true, tf.float32)
    
        # Nếu y_true là hard label → convert one-hot
        if len(y_true.shape) == 1:
            # Shape (batch,) → one_hot trực tiếp
            y_true = tf.one_hot(tf.cast(y_true, tf.int32), NUM_CLASSES)
        elif y_true.shape[-1] == 1:
            # Shape (batch, 1) → squeeze rồi one_hot
            y_true = tf.one_hot(tf.cast(tf.squeeze(y_true, axis=-1), tf.int32), NUM_CLASSES)
        # Còn lại: soft label (batch, num_classes) → giữ nguyên
    
        epsilon    = tf.keras.backend.epsilon()
        y_pred     = tf.clip_by_value(y_pred, epsilon, 1.0 - epsilon)
        ce_loss    = -y_true * tf.math.log(y_pred)
        p_t        = tf.reduce_sum(y_true * y_pred, axis=-1, keepdims=True)
        focal_wt   = self.alpha * tf.pow(1.0 - p_t, self.gamma)
        focal_loss = focal_wt * tf.reduce_sum(ce_loss, axis=-1, keepdims=True)
        return tf.reduce_mean(focal_loss)

    def get_config(self):
        base = super().get_config()
        base.update({'gamma': self.gamma, 'alpha': self.alpha})
        return base


class F1MacroMetric(tf.keras.metrics.Metric):
    """F1 Macro metric tính trên toàn epoch (accumulate predictions)."""
    def __init__(self, num_classes, name='f1_macro', **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion   = self.add_weight(
            name='confusion_matrix',
            shape=(num_classes, num_classes),
            initializer='zeros'
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Xử lý soft label (MixUp)
        if len(y_true.shape) > 1 and y_true.shape[-1] > 1:
            y_true = tf.argmax(y_true, axis=-1)
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)

        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes)
        self.confusion.assign_add(tf.cast(cm, tf.float32))

    def result(self):
        cm = self.confusion
        tp = tf.linalg.diag_part(cm)
        fp = tf.reduce_sum(cm, axis=0) - tp
        fn = tf.reduce_sum(cm, axis=1) - tp

        precision = tp / (tp + fp + 1e-7)
        recall    = tp / (tp + fn + 1e-7)
        f1        = 2 * precision * recall / (precision + recall + 1e-7)
        return tf.reduce_mean(f1)

    def reset_state(self):
        self.confusion.assign(tf.zeros_like(self.confusion))


# Test nhanh
fl   = FocalLoss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA)
y_t  = tf.constant([0, 1, 2], dtype=tf.int32)
y_p  = tf.one_hot(y_t, depth=NUM_CLASSES) * 0.9 + (0.1 / NUM_CLASSES)
print(f'✅ Focal Loss test: {fl(y_t, y_p).numpy():.4f}')

f1m  = F1MacroMetric(num_classes=NUM_CLASSES)
print(f'✅ F1 Macro Metric khởi tạo xong')
# Out:
# ✅ Focal Loss test: 0.0002
# ✅ F1 Macro Metric khởi tạo xong

# %% [markdown]
# ## 7. Xây dựng Model EfficientNetV2-M v2
#
# **Thay đổi so với v1:**
# - Head: `GAP → BN → Dense(512, relu) → Dropout(0.5) → Dense(256, relu) → Dropout(0.3) → Dense(30, softmax)`
# - Optimizer: **AdamW** (Adam + weight decay 1e-4) thay vì Adam
# - Loss: **Focal Loss**
# - Metric: thêm **F1 Macro**

# %%
def build_model(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=NUM_CLASSES,
                dropout1=0.5, dropout2=0.3, trainable_backbone=False):
    """
    EfficientNetV2-M với improved head:
    GAP → BN → Dense(512) → Dropout(0.5) → Dense(256) → Dropout(0.3) → Dense(30)
    """
    backbone = EfficientNetV2M(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        include_preprocessing=True    # tự normalize [0,255] → [-1,1]
    )
    backbone.trainable = trainable_backbone

    inputs  = tf.keras.Input(shape=input_shape)
    x       = backbone(inputs, training=False)
    x       = layers.GlobalAveragePooling2D()(x)
    x       = layers.BatchNormalization()(x)

    # Block 1
    x       = layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x       = layers.Activation('relu')(x)
    x       = layers.Dropout(dropout1)(x)

    # Block 2 (mới so với v1)
    x       = layers.Dense(256, kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x       = layers.Activation('relu')(x)
    x       = layers.Dropout(dropout2)(x)

    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model   = Model(inputs, outputs, name='EfficientNetV2M_v2')
    return model, backbone


with strategy.scope():
    model, backbone = build_model()

    model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=PHASE1_LR,
            weight_decay=1e-4
        ),
        loss=FocalLoss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
            F1MacroMetric(num_classes=NUM_CLASSES)
        ]
    )

model.summary(show_trainable=True, line_length=100)

# Đếm params
total      = model.count_params()
trainable  = sum(v.numpy().size for v in model.trainable_variables)
frozen     = total - trainable
print(f'\nTotal params    : {total:,}')
print(f'Trainable params: {trainable:,}  ({trainable/total*100:.1f}%)')
print(f'Frozen params   : {frozen:,}')
# Out:
# Model: "EfficientNetV2M_v2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                          ┃ Output Shape                  ┃        Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer_3 (InputLayer)            │ (None, 384, 384, 3)           │              0 │    -    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ efficientnetv2-m (Functional)         │ (None, 12, 12, 1280)          │     53,150,388 │    N    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ global_average_pooling2d_1            │ (None, 1280)                  │              0 │    -    │
# │ (GlobalAveragePooling2D)              │                               │                │         │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ batch_normalization_1                 │ (None, 1280)                  │          5,120 │    Y    │
# │ (BatchNormalization)                  │                               │                │         │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ dense_3 (Dense)                       │ (None, 512)                   │        655,872 │    Y    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ activation_2 (Activation)             │ (None, 512)                   │              0 │    -    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ dropout_2 (Dropout)                   │ (None, 512)                   │              0 │    -    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ dense_4 (Dense)                       │ (None, 256)                   │        131,328 │    Y    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ activation_3 (Activation)             │ (None, 256)                   │              0 │    -    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ dropout_3 (Dropout)                   │ (None, 256)                   │              0 │    -    │
# ├───────────────────────────────────────┼───────────────────────────────┼────────────────┼─────────┤
# │ dense_5 (Dense)                       │ (None, 30)                    │          7,710 │    Y    │
# └───────────────────────────────────────┴───────────────────────────────┴────────────────┴─────────┘
#  Total params: 53,950,418 (205.80 MB)
#  Trainable params: 797,470 (3.04 MB)
#  Non-trainable params: 53,152,948 (202.76 MB)
# Total params    : 53,950,418
# Trainable params: 797,470  (1.5%)
# Frozen params   : 53,152,948

# %% [markdown]
# ## 8. Kiểm tra Checkpoint & Resume Training

# %%
SEARCH_DIRS = [
    '/kaggle/input/notebooks/dart098/efficientnetv2-m/checkpoints',
    '/kaggle/working/checkpoints',
    '/kaggle/working',
    'checkpoints',
    '.',
]


def find_latest_phase1_checkpoint(search_dirs):
    """Tìm checkpoint phase 1 có epoch lớn nhất và in ra các path tìm được."""
    ckpts = []
    for base in search_dirs:
        if not base:
            continue
        ckpts.extend(glob.glob(os.path.join(base, 'phase1_epoch_*.weights.h5')))

    ckpts = sorted(set(os.path.normpath(fp) for fp in ckpts))

    print('🔎 Phase 1 checkpoints tìm được:')
    if ckpts:
        for fp in ckpts:
            print(f'  - {fp}')
    else:
        print('  (không tìm thấy file nào)')

    def extract_epoch(fp):
        m = re.search(r'phase1_epoch_(\d+)', os.path.basename(fp))
        return int(m.group(1)) if m else 0

    if not ckpts:
        return None, 0

    latest = max(ckpts, key=extract_epoch)
    return latest, extract_epoch(latest)


print(f'cwd          : {os.getcwd()}')
print(f'CKPT_DIR     : {CKPT_DIR}')
print(f'CKPT_DIR exist: {os.path.exists(CKPT_DIR)}')

if START_FROM_SCRATCH:
    print('\n🆕 START_FROM_SCRATCH=True — bỏ qua checkpoint phase 1')
    resume_path_1, resume_epoch_1 = None, 0
else:
    resume_path_1, resume_epoch_1 = find_latest_phase1_checkpoint(SEARCH_DIRS)

if resume_path_1:
    print(f'\n🔄 Load phase 1 checkpoint mới nhất: {resume_path_1}')
    print(f'   Resume từ epoch {resume_epoch_1 + 1}')
    model.load_weights(resume_path_1)
else:
    print('\n🆕 Bắt đầu train phase 1 từ đầu')
    resume_epoch_1 = 0
# Out:
# cwd          : /kaggle/working
# CKPT_DIR     : /kaggle/working/checkpoints
# CKPT_DIR exist: True
#
# 🆕 START_FROM_SCRATCH=True — bỏ qua checkpoint phase 1
#
# 🆕 Bắt đầu train phase 1 từ đầu

# %% [markdown]
# ## 9. Phase 1 — Train (Freeze Backbone)
#
# Freeze toàn bộ backbone, chỉ train classifier head.
# - **15 epochs** (tăng từ 10) để head ổn định trước khi unfreeze
# - Monitor **val_f1_macro** để lưu best model
# - LR schedule: ReduceLROnPlateau khi val_f1_macro không tăng sau 3 epochs

# %%
# ── Callbacks Phase 1 ──
ckpt_cb_p1 = ModelCheckpoint(
    filepath=os.path.join(CKPT_DIR, 'phase1_epoch_{epoch:02d}.weights.h5'),
    save_weights_only=True,
    save_freq='epoch',
    verbose=0
)

best_cb = ModelCheckpoint(
    filepath=BEST_WEIGHT,
    save_weights_only=True,
    monitor='val_f1_macro',
    mode='max',
    save_best_only=True,
    verbose=1
)

early_cb = EarlyStopping(
    monitor='val_f1_macro',
    mode='max',
    patience=7,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_p1 = ReduceLROnPlateau(
    monitor='val_f1_macro',
    mode='max',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

csv_cb = CSVLogger(LOG_CSV, append=False if START_FROM_SCRATCH else True)

callbacks_p1 = [ckpt_cb_p1, best_cb, early_cb, reduce_lr_p1, csv_cb]

# ── Resume / Train Phase 1 ──
if START_FROM_SCRATCH:
    print('🆕 START_FROM_SCRATCH=True — train phase 1 từ đầu')
    resume_epoch = 0
else:
    if resume_path_1:
        print(f'🔄 Resume Phase 1 từ: {resume_path_1}')
        print(f'   Resume từ epoch {resume_epoch_1 + 1}')
        model.load_weights(resume_path_1)
        resume_epoch = resume_epoch_1
    else:
        print('🆕 Không có checkpoint phase 1 — bắt đầu train từ đầu')
        resume_epoch = 0

if resume_epoch < PHASE1_EPOCHS:
    print(f'\n🚀 Phase 1 — Freeze Backbone | {PHASE1_EPOCHS - resume_epoch} epochs')
    print(f'   LR = {PHASE1_LR} | Loss = Focal(gamma={FOCAL_GAMMA}, alpha={FOCAL_ALPHA})')
    print(f'   Monitor: val_f1_macro (best checkpoint)')
    print('─' * 60)

    hist_p1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=PHASE1_EPOCHS,
        initial_epoch=resume_epoch,
        callbacks=callbacks_p1,
        verbose=1
    )
else:
    print(f'✅ Phase 1 đã hoàn thành (checkpoint epoch {resume_epoch}). Bỏ qua.')
    hist_p1 = None
# Out:
# 🆕 START_FROM_SCRATCH=True — train phase 1 từ đầu
#
# 🚀 Phase 1 — Freeze Backbone | 15 epochs
#    LR = 0.001 | Loss = Focal(gamma=2.0, alpha=0.25)
#    Monitor: val_f1_macro (best checkpoint)
# ────────────────────────────────────────────────────────────
# Epoch 1/15
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1782288644.916714      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetV2M_v2_1/efficientnetv2-m_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0974 - f1_macro: 0.0679 - loss: 1.7442
# Epoch 1: val_f1_macro improved from None to 0.13198, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 439s 3s/step - accuracy: 0.1315 - f1_macro: 0.0932 - loss: 1.5980 - val_accuracy: 0.0413 - val_f1_macro: 0.1320 - val_loss: 1.4461 - learning_rate: 0.0010
# Epoch 2/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1836 - f1_macro: 0.1369 - loss: 1.4225
# Epoch 2: val_f1_macro improved from 0.13198 to 0.25184, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 388s 3s/step - accuracy: 0.1926 - f1_macro: 0.1495 - loss: 1.3974 - val_accuracy: 0.0395 - val_f1_macro: 0.2518 - val_loss: 1.1719 - learning_rate: 0.0010
# Epoch 3/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2224 - f1_macro: 0.1711 - loss: 1.3346
# Epoch 3: val_f1_macro improved from 0.25184 to 0.34455, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 3: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 391s 3s/step - accuracy: 0.2190 - f1_macro: 0.1820 - loss: 1.3350 - val_accuracy: 0.0366 - val_f1_macro: 0.3445 - val_loss: 0.9265 - learning_rate: 0.0010
# Epoch 4/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2461 - f1_macro: 0.1997 - loss: 1.2953
# Epoch 4: val_f1_macro improved from 0.34455 to 0.34810, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 4: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 396s 3s/step - accuracy: 0.2511 - f1_macro: 0.2149 - loss: 1.2851 - val_accuracy: 0.0360 - val_f1_macro: 0.3481 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 5/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2507 - f1_macro: 0.2148 - loss: 1.2710
# Epoch 5: val_f1_macro improved from 0.34810 to 0.41554, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 5: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 396s 3s/step - accuracy: 0.2599 - f1_macro: 0.2291 - loss: 1.2578 - val_accuracy: 0.0454 - val_f1_macro: 0.4155 - val_loss: 0.7910 - learning_rate: 0.0010
# Epoch 6/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2731 - f1_macro: 0.2470 - loss: 1.2343
# Epoch 6: val_f1_macro improved from 0.41554 to 0.42486, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 395s 3s/step - accuracy: 0.2739 - f1_macro: 0.2483 - loss: 1.2283 - val_accuracy: 0.0401 - val_f1_macro: 0.4249 - val_loss: 0.7552 - learning_rate: 0.0010
# Epoch 7/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2847 - f1_macro: 0.2537 - loss: 1.2019
# Epoch 7: val_f1_macro improved from 0.42486 to 0.45365, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 390s 3s/step - accuracy: 0.2951 - f1_macro: 0.2681 - loss: 1.1940 - val_accuracy: 0.0419 - val_f1_macro: 0.4537 - val_loss: 0.7256 - learning_rate: 0.0010
# Epoch 8/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2955 - f1_macro: 0.2632 - loss: 1.1900
# Epoch 8: val_f1_macro did not improve from 0.45365
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 386s 3s/step - accuracy: 0.2889 - f1_macro: 0.2621 - loss: 1.2018 - val_accuracy: 0.0401 - val_f1_macro: 0.4450 - val_loss: 0.7259 - learning_rate: 0.0010
# Epoch 9/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3126 - f1_macro: 0.2789 - loss: 1.1735
# Epoch 9: val_f1_macro did not improve from 0.45365
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 388s 3s/step - accuracy: 0.3105 - f1_macro: 0.2807 - loss: 1.1759 - val_accuracy: 0.0437 - val_f1_macro: 0.4464 - val_loss: 0.7049 - learning_rate: 0.0010
# Epoch 10/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3190 - f1_macro: 0.2808 - loss: 1.1643
# Epoch 10: val_f1_macro improved from 0.45365 to 0.49121, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 10: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 393s 3s/step - accuracy: 0.3183 - f1_macro: 0.2873 - loss: 1.1678 - val_accuracy: 0.0437 - val_f1_macro: 0.4912 - val_loss: 0.6689 - learning_rate: 0.0010
# Epoch 11/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3259 - f1_macro: 0.2966 - loss: 1.1391
# Epoch 11: val_f1_macro improved from 0.49121 to 0.49971, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 11: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 388s 3s/step - accuracy: 0.3243 - f1_macro: 0.2984 - loss: 1.1436 - val_accuracy: 0.0419 - val_f1_macro: 0.4997 - val_loss: 0.6592 - learning_rate: 0.0010
# Epoch 12/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3423 - f1_macro: 0.3037 - loss: 1.1296
# Epoch 12: val_f1_macro improved from 0.49971 to 0.51211, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 12: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 388s 3s/step - accuracy: 0.3347 - f1_macro: 0.3104 - loss: 1.1378 - val_accuracy: 0.0372 - val_f1_macro: 0.5121 - val_loss: 0.6504 - learning_rate: 0.0010
# Epoch 13/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3327 - f1_macro: 0.3030 - loss: 1.1298
# Epoch 13: val_f1_macro did not improve from 0.51211
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - accuracy: 0.3456 - f1_macro: 0.3215 - loss: 1.1208 - val_accuracy: 0.0395 - val_f1_macro: 0.5077 - val_loss: 0.6423 - learning_rate: 0.0010
# Epoch 14/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3432 - f1_macro: 0.3162 - loss: 1.1173
# Epoch 14: val_f1_macro improved from 0.51211 to 0.52617, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 14: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.3419 - f1_macro: 0.3163 - loss: 1.1204 - val_accuracy: 0.0383 - val_f1_macro: 0.5262 - val_loss: 0.6168 - learning_rate: 0.0010
# Epoch 15/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3419 - f1_macro: 0.3103 - loss: 1.1215
# Epoch 15: val_f1_macro improved from 0.52617 to 0.54565, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 391s 3s/step - accuracy: 0.3460 - f1_macro: 0.3219 - loss: 1.1134 - val_accuracy: 0.0389 - val_f1_macro: 0.5456 - val_loss: 0.6203 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# ## 10. Phase 2 — Fine-tune (Unfreeze dần từ top → bottom)
#
# **Thay đổi quan trọng so với v1:**
# - v1: unfreeze **toàn bộ backbone** cùng lúc → val loss spike
# - v2: **unfreeze từng block** theo lịch:
#   - Epoch 1–5: Unfreeze top 20 layers (block7)
#   - Epoch 6–15: Unfreeze top 60 layers (block5–7)
#   - Epoch 16–30: Unfreeze toàn bộ
# - LR bắt đầu **5e-5** (nhỏ hơn v1) và giảm dần bằng cosine decay

# %%
# ── Phase 2 helpers ──
SEARCH_DIRS_P2 = [
    '/kaggle/input/notebooks/dart098/efficientnetv2-m/checkpoints',
    '/kaggle/working/checkpoints',
    '/kaggle/working',
    'checkpoints',
    '.',
]


def find_latest_phase2_checkpoint(search_dirs):
    """Tìm checkpoint phase 2 có epoch lớn nhất và in ra các path tìm được."""
    ckpts = []
    for base in search_dirs:
        if not base:
            continue
        ckpts.extend(
            glob.glob(os.path.join(base, '**', 'phase2_epoch_*.weights.h5'), recursive=True)
        )

    ckpts = sorted(set(os.path.normpath(fp) for fp in ckpts))

    print('🔎 Phase 2 checkpoints tìm được:')
    if ckpts:
        for fp in ckpts:
            print(f'  - {fp}')
    else:
        print('  (không tìm thấy file nào)')

    def extract_epoch(fp):
        m = re.search(r'phase2_epoch_(\d+)', os.path.basename(fp))
        return int(m.group(1)) if m else 0

    if not ckpts:
        return None, 0

    latest = max(ckpts, key=extract_epoch)
    return latest, extract_epoch(latest)


def set_trainable_top_n(backbone, n_layers):
    """Unfreeze n_layers cuối của backbone."""
    if n_layers is None:
        backbone.trainable = True
        print(f'  Unfreeze toàn bộ backbone ({len(backbone.layers)} layers)')
    else:
        backbone.trainable = False
        for layer in backbone.layers[-n_layers:]:
            if not isinstance(layer, tf.keras.layers.BatchNormalization):
                layer.trainable = True
        n_trainable = sum(1 for l in backbone.layers if l.trainable)
        print(f'  Unfreeze top {n_layers} layers ({n_trainable} trainable layers)')


def make_cosine_schedule(initial_lr, total_steps):
    return tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=initial_lr,
        decay_steps=total_steps,
        alpha=1e-6
    )


def compile_phase2_model():
    total_steps = PHASE2_EPOCHS * len(train_ds_p2)
    lr_schedule = make_cosine_schedule(PHASE2_LR, total_steps)
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay=1e-4
        ),
        loss=FocalLoss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
            F1MacroMetric(num_classes=NUM_CLASSES)
        ]
    )


# ── Callbacks Phase 2 ──
ckpt_cb_p2 = ModelCheckpoint(
    filepath=os.path.join(CKPT_DIR, 'phase2_epoch_{epoch:02d}.weights.h5'),
    save_weights_only=True,
    save_freq='epoch',
    verbose=0
)

best_cb_p2 = ModelCheckpoint(
    filepath=BEST_WEIGHT,
    save_weights_only=True,
    monitor='val_f1_macro',
    mode='max',
    save_best_only=True,
    verbose=1
)

early_cb_p2 = EarlyStopping(
    monitor='val_f1_macro',
    mode='max',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

csv_cb_p2 = CSVLogger(LOG_CSV, append=True)
callbacks_p2 = [ckpt_cb_p2, best_cb_p2, early_cb_p2, csv_cb_p2]


# ── Resume Phase 2 ──
print('\n🔧 Phase 2 setup:')
print(f'  LR khởi đầu   : {PHASE2_LR} (cosine decay → 1e-6)')
print(f'  Unfreeze plan  : frozen 0–1 → top20 2–4 → top60 5+')
print(f'  EarlyStopping  : patience=10 trên val_f1_macro')

if START_FROM_SCRATCH:
    print('🆕 START_FROM_SCRATCH=True — không resume phase 2')
    resume_path_2, resume_epoch_2 = None, 0
else:
    resume_path_2, resume_epoch_2 = find_latest_phase2_checkpoint(SEARCH_DIRS_P2)

if resume_path_2:
    print(f'🔄 Resume Phase 2 từ: {resume_path_2}')
    print(f'   Resume từ epoch {resume_epoch_2 + 1}')
    model.load_weights(resume_path_2)
    resume_local_epoch = max(0, resume_epoch_2 - PHASE1_EPOCHS)
else:
    base_phase1_ckpt = None if START_FROM_SCRATCH else globals().get('resume_path_1', None)
    if base_phase1_ckpt:
        print(f'🆕 Không có checkpoint phase 2 — fallback về phase 1: {base_phase1_ckpt}')
        model.load_weights(base_phase1_ckpt)
    else:
        print('🆕 Không có checkpoint — bắt đầu phase 2 từ model hiện tại')
    resume_local_epoch = 0

print(f'   Local phase 2 epoch hiện tại: {resume_local_epoch}')


# ── Train Phase 2 theo từng stage riêng ──
phase2_segments = [
    ('Frozen backbone', 0, min(2, PHASE2_EPOCHS), 0),
    ('Top 20 layers',   2, min(5, PHASE2_EPOCHS), 20),
    ('Top 60 layers',   5, PHASE2_EPOCHS, 60),
]

histories_p2 = []

if resume_local_epoch >= PHASE2_EPOCHS:
    print('\n✅ Phase 2 đã hoàn thành trước đó — bỏ qua fit.')
    hist_p2 = None
else:
    print('\n🚀 Phase 2 — Fine-tune dần | tối đa', PHASE2_EPOCHS, 'epochs')
    print('─' * 60)

    for stage_name, stage_start, stage_end, n_layers in phase2_segments:
        if resume_local_epoch >= stage_end:
            continue

        fit_start_local = max(resume_local_epoch, stage_start)
        if fit_start_local >= stage_end:
            continue

        print(f'\n📌 Stage: {stage_name} | local epoch {fit_start_local + 1} → {stage_end}')

        with strategy.scope():
            if n_layers == 0:
                backbone.trainable = False
                print('  Giữ backbone frozen')
            else:
                set_trainable_top_n(backbone, n_layers)
            compile_phase2_model()

        hist = model.fit(
            train_ds_p2,
            validation_data=val_ds,
            epochs=PHASE1_EPOCHS + stage_end,
            initial_epoch=PHASE1_EPOCHS + fit_start_local,
            callbacks=callbacks_p2,
            verbose=1
        )
        histories_p2.append(hist)
        resume_local_epoch = stage_end

    hist_p2 = histories_p2[-1] if histories_p2 else None
# Out:
# 🔧 Phase 2 setup:
#   LR khởi đầu   : 0.0001 (cosine decay → 1e-6)
#   Unfreeze plan  : frozen 0–1 → top20 2–4 → top60 5+
#   EarlyStopping  : patience=10 trên val_f1_macro
# 🆕 START_FROM_SCRATCH=True — không resume phase 2
# 🆕 Không có checkpoint — bắt đầu phase 2 từ model hiện tại
#    Local phase 2 epoch hiện tại: 0
#
# 🚀 Phase 2 — Fine-tune dần | tối đa 30 epochs
# ────────────────────────────────────────────────────────────
#
# 📌 Stage: Frozen backbone | local epoch 1 → 2
#   Giữ backbone frozen
# Epoch 16/17
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1782294805.293133      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetV2M_v2_1/efficientnetv2-m_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0329 - f1_macro: 0.4588 - loss: 0.7462
# Epoch 16: val_f1_macro improved from None to 0.59243, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 16: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 418s 3s/step - accuracy: 0.0344 - f1_macro: 0.4729 - loss: 0.7325 - val_accuracy: 0.0425 - val_f1_macro: 0.5924 - val_loss: 0.5628
# Epoch 17/17
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0344 - f1_macro: 0.4925 - loss: 0.6838
# Epoch 17: val_f1_macro improved from 0.59243 to 0.60132, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 17: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - accuracy: 0.0324 - f1_macro: 0.5074 - loss: 0.6793 - val_accuracy: 0.0413 - val_f1_macro: 0.6013 - val_loss: 0.5398
# Restoring model weights from the end of the best epoch: 17.
#
# 📌 Stage: Top 20 layers | local epoch 3 → 5
#   Unfreeze top 20 layers (16 trainable layers)
# Epoch 18/20
# INFO:tensorflow:Collective all_reduce tensors: 16 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1782295617.759060      58 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetV2M_v2_1/efficientnetv2-m_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0257 - f1_macro: 0.5045 - loss: 0.6672
# Epoch 18: val_f1_macro improved from 0.60132 to 0.62827, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 428s 3s/step - accuracy: 0.0315 - f1_macro: 0.5237 - loss: 0.6508 - val_accuracy: 0.0413 - val_f1_macro: 0.6283 - val_loss: 0.5059
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0291 - f1_macro: 0.5258 - loss: 0.6207
# Epoch 19: val_f1_macro improved from 0.62827 to 0.66181, saving model to /kaggle/working/best_weights.weights.h5
#
# Epoch 19: finished saving model to /kaggle/working/best_weights.weights.h5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.0279 - f1_macro: 0.5463 - loss: 0.6010 - val_accuracy: 0.0431 - val_f1_macro: 0.6618 - val_loss: 0.4695
# Epoch 20/20
#  12/141 ━━━━━━━━━━━━━━━━━━━━ 5:21 2s/step - accuracy: 0.0255 - f1_macro: 0.5264 - loss: 0.5599

# %% [markdown]
# ## 11. Visualize Learning Curves

# %%
# ── Đọc log từ CSV (bao gồm cả 2 phase) ──
log_df = pd.read_csv(LOG_CSV)
log_df['epoch'] = log_df['epoch'] + 1   # 1-indexed

fig = plt.figure(figsize=(18, 10))
gs  = gridspec.GridSpec(2, 3, figure=fig)

ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])
ax4 = fig.add_subplot(gs[1, 2])

# ── Loss ──
ax1.plot(log_df['epoch'], log_df['loss'],     'b-', label='Train Loss', linewidth=1.5)
ax1.plot(log_df['epoch'], log_df['val_loss'], 'r-', label='Val Loss',   linewidth=1.5)
ax1.axvline(PHASE1_EPOCHS, color='gray', linestyle='--', alpha=0.7, label=f'Phase 2 bắt đầu (epoch {PHASE1_EPOCHS})')
ax1.set_title('Focal Loss theo Epoch', fontsize=12)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

# ── Accuracy ──
acc_col = 'accuracy' if 'accuracy' in log_df.columns else 'categorical_accuracy'
ax2.plot(log_df['epoch'], log_df[acc_col],         'b-', label='Train Acc')
ax2.plot(log_df['epoch'], log_df[f'val_{acc_col}'],'r-', label='Val Acc')
ax2.axvline(PHASE1_EPOCHS, color='gray', linestyle='--', alpha=0.7)
ax2.set_title('Accuracy theo Epoch')
ax2.set_xlabel('Epoch')
ax2.legend()
ax2.grid(True, alpha=0.3)

# ── F1 Macro ──
if 'f1_macro' in log_df.columns:
    best_f1  = log_df['val_f1_macro'].max()
    best_ep  = log_df.loc[log_df['val_f1_macro'].idxmax(), 'epoch']
    ax3.plot(log_df['epoch'], log_df['f1_macro'],     'b-', label='Train F1')
    ax3.plot(log_df['epoch'], log_df['val_f1_macro'], 'r-', label='Val F1')
    ax3.axhline(best_f1, color='green', linestyle=':', alpha=0.8,
                label=f'Best val F1: {best_f1:.4f} (epoch {best_ep:.0f})')
    ax3.axvline(PHASE1_EPOCHS, color='gray', linestyle='--', alpha=0.7)
    ax3.set_title('F1 Macro theo Epoch')
    ax3.set_xlabel('Epoch')
    ax3.legend()
    ax3.grid(True, alpha=0.3)

# ── LR ──
if 'lr' in log_df.columns:
    ax4.semilogy(log_df['epoch'], log_df['lr'], 'g-')
    ax4.axvline(PHASE1_EPOCHS, color='gray', linestyle='--', alpha=0.7)
    ax4.set_title('Learning Rate theo Epoch')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('LR (log scale)')
    ax4.grid(True, alpha=0.3)

plt.suptitle('Learning Curves — EfficientNetV2-M v2 | Brain Tumor 30 Classes', fontsize=14)
plt.tight_layout()
plt.savefig('/kaggle/working/learning_curves_v2.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 12. Đánh giá trên Test Set

# %%
# ── Load best weights ──
print(f'📂 Load best weights từ: {BEST_WEIGHT}')
model.load_weights(BEST_WEIGHT)

# ── Dự đoán ──
print('\n🔍 Đang dự đoán test set...')
y_pred_probs = model.predict(test_ds, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

# ── Ground truth (test_ds không shuffle) ──
y_true = test_df['label'].values

# Metrics
acc         = accuracy_score(y_true, y_pred)
f1_macro    = f1_score(y_true, y_pred, average='macro',    zero_division=0)
f1_weighted = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'\n{"="*55}')
print(f'       KẾT QUẢ ĐÁNH GIÁ TRÊN TEST SET')
print(f'{"="*55}')
print(f'  Accuracy         : {acc:.4f}  ({acc*100:.2f}%)')
print(f'  F1-score Macro   : {f1_macro:.4f}')
print(f'  F1-score Weighted: {f1_weighted:.4f}')
print(f'{"="*55}')

# %%
# ── Classification Report ──
report = classification_report(
    y_true, y_pred,
    target_names=CLASS_NAMES,
    digits=4
)
print('Classification Report:')
print(report)

with open('/kaggle/working/classification_report_v2.txt', 'w') as f:
    f.write('KẾT QUẢ ĐÁNH GIÁ TRÊN TEST SET (v2)\n')
    f.write(f'Accuracy         : {acc:.4f}\n')
    f.write(f'F1-score Macro   : {f1_macro:.4f}\n')
    f.write(f'F1-score Weighted: {f1_weighted:.4f}\n\n')
    f.write(report)
print('✅ Đã lưu classification_report_v2.txt')

# %%
# ── Confusion Matrix ──
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(22, 18))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
    linewidths=0.3, ax=ax
)
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
ax.set_title(
    f'Confusion Matrix — Test Set (v2)\n'
    f'Accuracy: {acc:.4f} | F1 Macro: {f1_macro:.4f} | F1 Weighted: {f1_weighted:.4f}',
    fontsize=13
)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.savefig('/kaggle/working/confusion_matrix_v2.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── F1-score từng class ──
f1_per_class = f1_score(y_true, y_pred, average=None, zero_division=0)

fig, ax = plt.subplots(figsize=(16, 7))
colors = ['#27ae60' if f >= 0.8 else '#e67e22' if f >= 0.5 else '#e74c3c'
          for f in f1_per_class]
ax.bar(range(NUM_CLASSES), f1_per_class, color=colors, edgecolor='white')
ax.set_xticks(range(NUM_CLASSES))
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=8)
ax.set_ylabel('F1-score')
ax.set_ylim(0, 1.05)
ax.axhline(f1_macro, color='navy', linestyle='--', label=f'F1 Macro: {f1_macro:.4f}')
ax.axhline(0.8, color='green', linestyle=':', alpha=0.5, label='Ngưỡng tốt (0.8)')
ax.axhline(0.5, color='orange', linestyle=':', alpha=0.5, label='Ngưỡng chấp nhận (0.5)')
ax.set_title('F1-score theo từng Class (v2)\n(🟢 ≥0.8 | 🟠 0.5–0.8 | 🔴 <0.5)', fontsize=13)
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('/kaggle/working/f1_per_class_v2.png', dpi=150, bbox_inches='tight')
plt.show()

# Classes yếu nhất
weak = [(CLASS_NAMES[i], f1_per_class[i]) for i in np.argsort(f1_per_class)[:5]]
print('\n5 class yếu nhất:')
for name, f1 in weak:
    print(f'  {name:<30} F1={f1:.4f}')

# %% [markdown]
# ## 13. Visualize Kết quả Dự đoán

# %%
def show_predictions(df_subset, y_true_arr, y_pred_arr, y_probs_arr,
                     title, n=12, correct=True):
    if correct:
        idxs = np.where(y_true_arr == y_pred_arr)[0]
    else:
        idxs = np.where(y_true_arr != y_pred_arr)[0]

    if len(idxs) == 0:
        print(f'Không có ảnh nào ({title})')
        return

    chosen = np.random.choice(idxs, size=min(n, len(idxs)), replace=False)
    ncols  = 4
    nrows  = (len(chosen) + ncols - 1) // ncols

    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 4))
    for ax in axes.flat:
        ax.axis('off')

    for ax, i in zip(axes.flat, chosen):
        img      = plt.imread(df_subset.iloc[i]['filepath'])
        true_lbl = CLASS_NAMES[y_true_arr[i]]
        pred_lbl = CLASS_NAMES[y_pred_arr[i]]
        conf     = y_probs_arr[i][y_pred_arr[i]]
        color    = '#27ae60' if correct else '#e74c3c'
        ax.imshow(img, cmap='gray')
        ax.set_title(
            f'True : {true_lbl}\nPred : {pred_lbl}\nConf : {conf:.2%}',
            fontsize=7.5, color=color
        )
        ax.axis('off')

    plt.suptitle(title, fontsize=13, fontweight='bold')
    plt.tight_layout()
    fname = title.lower().replace(' ', '_').replace('✅','ok').replace('❌','err').replace('(','').replace(')','') + '.png'
    plt.savefig(f'/kaggle/working/{fname}', dpi=150, bbox_inches='tight')
    plt.show()


np.random.seed(RANDOM_SEED)
show_predictions(test_df, y_true, y_pred, y_pred_probs,
                 title='✅ Dự đoán ĐÚNG (correct predictions)', n=12, correct=True)
show_predictions(test_df, y_true, y_pred, y_pred_probs,
                 title='❌ Dự đoán SAI (wrong predictions)',   n=12, correct=False)

# %%
# ── Tóm tắt kết quả ──
print('\n' + '═' * 60)
print('   📊 TÓM TẮT KẾT QUẢ — EfficientNetV2-M v2')
print('═' * 60)
print(f'   Model         : EfficientNetV2-M v2')
print(f'   Dataset       : Brain Tumor MRI 30 Classes')
print(f'   Tổng ảnh      : {len(df):,} | {df["class_name"].nunique()} classes')
print(f'   Split         : 70/15/15 (theo class_name)')
print(f'   IMG SIZE      : {IMG_SIZE}×{IMG_SIZE}  (↓ từ 480)')
print(f'   Batch size    : {BATCH_SIZE}')
print(f'   Loss          : Focal Loss (γ={FOCAL_GAMMA}, α={FOCAL_ALPHA})')
print(f'   Augmentation  : flip, rotation, zoom, erasing, MixUp')
print(f'   Optimizer     : AdamW + weight_decay=1e-4')
print('─' * 60)
print(f'   Accuracy         : {acc:.4f}  ({acc*100:.2f}%)')
print(f'   F1-score Macro   : {f1_macro:.4f}')
print(f'   F1-score Weighted: {f1_weighted:.4f}')
print('─' * 60)
print(f'   Best weights  : {BEST_WEIGHT}')
print('═' * 60)

summary = {
    'version'        : 'v2',
    'model'          : 'EfficientNetV2-M',
    'img_size'       : IMG_SIZE,
    'num_classes'    : NUM_CLASSES,
    'class_names'    : CLASS_NAMES,
    'random_seed'    : RANDOM_SEED,
    'loss'           : f'FocalLoss(gamma={FOCAL_GAMMA}, alpha={FOCAL_ALPHA})',
    'optimizer'      : 'AdamW(weight_decay=1e-4)',
    'augmentation'   : 'flip, rotation, zoom, brightness, random_erasing, mixup',
    'test_accuracy'  : float(acc),
    'f1_macro'       : float(f1_macro),
    'f1_weighted'    : float(f1_weighted),
    'best_weight_path': BEST_WEIGHT
}
with open('/kaggle/working/model_summary_v2.json', 'w') as f:
    json.dump(summary, f, indent=2, ensure_ascii=False)
print('\n✅ Đã lưu model_summary_v2.json')

# %% [markdown]
# ---
#
# ## 📦 Hướng dẫn dùng best_weights trên Streamlit
#
# ```python
# import tensorflow as tf
# from tensorflow.keras.applications import EfficientNetV2M
# from tensorflow.keras import layers, Model
# import numpy as np
#
# IMG_SIZE    = 384   # ← v2 dùng 384, không phải 480
# NUM_CLASSES = 30
#
# # 1. Tái tạo kiến trúc (phải giống hệt lúc train)
# backbone = EfficientNetV2M(
#     include_top=False,
#     weights=None,
#     input_shape=(IMG_SIZE, IMG_SIZE, 3),
#     include_preprocessing=True
# )
# inputs  = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
# x       = backbone(inputs, training=False)
# x       = layers.GlobalAveragePooling2D()(x)
# x       = layers.BatchNormalization()(x)
# x       = layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
# x       = layers.Activation('relu')(x)
# x       = layers.Dropout(0.5)(x)
# x       = layers.Dense(256, kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
# x       = layers.Activation('relu')(x)
# x       = layers.Dropout(0.3)(x)
# outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)
# model   = Model(inputs, outputs)
#
# # 2. Load trọng số
# model.load_weights('best_weights.weights.h5')
#
# # 3. Dự đoán
# img   = tf.image.resize(your_image_rgb, [IMG_SIZE, IMG_SIZE])
# img   = tf.expand_dims(img, 0)   # [1, 384, 384, 3]
# preds = model.predict(img)       # [1, 30]
# class_idx  = np.argmax(preds[0])
# confidence = preds[0][class_idx]
# ```
#
# > ⚠️ Nhớ dùng `IMG_SIZE=384` (không phải 480) khi load model v2
